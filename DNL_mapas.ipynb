# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/meguia/DNL_unq/blob/main/DNL_mapas.ipynb)

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# # Funciones Iteradas

# %% [markdown]
# ## Funciones Lineales

# %% [markdown]
# Una Funcion me devuelve a la salida un **UNICO** valor que depende **SOLO** de la entrada (es **DETERMINISTA**).

# %%
def f(x):
  return 2*x

# %%
f(150)
# Out:
# 300

# %% [markdown]
# **ITERAR** una funcion es volver a meter la salida de la funcion en la entrada (Feedback positivo), o bien volver a aplicar la funcion de forma **recursiva **

# %%
f(f(f(f(0.1))))
# Out:
# 0.1

# %% [markdown]
# Mas claro es hacer una TABLA de valores sucesivos de la iteracion llamando $x_n$ a la n-esima iteracion de la funcion

# %%
x0 = 0.1
x1 = f(x0)
x2 = f(x1)
x3 = f(x2)
x4 = f(x3)
[x0,x1,x2,x3,x4]
# Out:
# [0.1,
#  0.09000000000000001,
#  0.08100000000000002,
#  0.07290000000000002,
#  0.06561000000000002]

# %% [markdown]
# Esto se puede hacer de forma recursiva usando un bucle *for* una cantidad fija de veces y guardando los valores $x_n$ en un array.
#
# **T** es la cantidad de veces que vamos a iterar, para aludir al **TIEMPO**. el array $x_n$ se llama **TRAYECTORIA** u **ORBITA**

# %%
T = 100
x = 0.1
xn = [x]
for t in range(T):
  x = f(x)
  xn.append(x)  
print(xn)
# Out:
# [0.1, 0.15000000000000002, 0.22500000000000003, 0.3375, 0.5062500000000001, 0.7593750000000001, 1.1390625, 1.7085937500000001, 2.562890625, 3.8443359375000004, 5.7665039062500005, 8.649755859375, 12.974633789062501, 19.461950683593752, 29.192926025390626, 43.78938903808594, 65.68408355712891, 98.52612533569337, 147.78918800354006, 221.6837820053101, 332.5256730079651, 498.78850951194767, 748.1827642679215, 1122.2741464018823, 1683.4112196028234, 2525.116829404235, 3787.6752441063527, 5681.512866159529, 8522.269299239293, 12783.40394885894, 19175.10592328841, 28762.658884932614, 43143.988327398925, 64715.98249109839, 97073.97373664757, 145610.96060497136, 218416.44090745703, 327624.66136118554, 491436.9920417783, 737155.4880626674, 1105733.232094001, 1658599.8481410015, 2487899.7722115023, 3731849.6583172535, 5597774.48747588, 8396661.731213821, 12594992.59682073, 18892488.895231098, 28338733.342846647, 42508100.01426997, 63762150.02140495, 95643225.03210743, 143464837.54816115, 215197256.32224172, 322795884.48336256, 484193826.72504383, 726290740.0875658, 1089436110.1313486, 1634154165.197023, 2451231247.795534, 3676846871.693301, 5515270307.539951, 8272905461.309927, 12409358191.96489, 18614037287.947334, 27921055931.921, 41881583897.8815, 62822375846.82225, 94233563770.23337, 141350345655.35004, 212025518483.02505, 318038277724.5376, 477057416586.8064, 715586124880.2096, 1073379187320.3145, 1610068780980.4717, 2415103171470.7075, 3622654757206.0615, 5433982135809.092, 8150973203713.638, 12226459805570.457, 18339689708355.688, 27509534562533.53, 41264301843800.3, 61896452765700.445, 92844679148550.67, 139267018722826.0, 208900528084239.0, 313350792126358.5, 470026188189537.75, 705039282284306.6, 1057558923426460.0, 1586338385139690.0, 2379507577709535.0, 3569261366564302.5, 5353892049846454.0, 8030838074769681.0, 1.2046257112154522e+16, 1.8069385668231784e+16, 2.7104078502347676e+16, 4.065611775352151e+16]

# %% [markdown]
# Y podemos graficar el resultado usando la funcion plot de matplotlib

# %%
T = 100
x = 1
xn = [x]
for t in range(T):
  x = f(x)
  xn.append(x)

# %%
rcParams['figure.figsize'] = (20, 5)
plt.plot(xn,'o-');

# %%
plt.semilogy(xn,'o-');

# %% [markdown]
# ## Funciones No Lineales

# %%
def f(x):
  return x*x

# %%
T = 10
x = 1.5
xn = [x]
for t in range(T):
  x = f(x)
  xn.append(x)
print(xn)
plt.semilogy(xn,'-o')
# Out:
# [1.5, 2.25, 5.0625, 25.62890625, 656.8408355712891, 431439.8832739892, 186140372879.47342, 3.4648238415709404e+22, 1.2005004253118409e+45, 1.441201271173911e+90, 2.0770611040332967e+180]

# %% [markdown]
# # Sistema Dinamico
#
# **Un sistema dinamico es un sistema que evoluciona en el tiempo siguiendo una regla determinista fija.**
#
# El sistema dinamico puede tener varias variables, en este caso estamos viendo la evolucion de una **unica** variable (x) por eso el sistema es **1D** (evoluciona en la recta)
#
# La Regla determinista es fija durante la evolucion pero puede depender de uno o mas **parametros**.
#
# Gran parte del estudio de los Sistemas Dinamicos se dedica a estudiar como cambian cualitativamente la evolucion temporal del sistema cuando cambian los parametros (Teoria de Bifurcaciones)

# %% [markdown]
# ## Mapa (sistema dinamico discreto en el tiempo)
# iteracion de una funcion en el tiempo
#
# $x_{n+1}=f(x_n)$
#
# Ejemplo funcion no lineal cuadratica
#
# $x_{n+1}=x_n^2$

# %%
# multiples condiciones iniciales
T = 12
xini = [0.01, 0.2, 0.5, 0.9, 0.999, 1]
for x in xini:
  xn = [x]
  for t in range(T):
    x = f(x)
    xn.append(x)
  plt.plot(xn,'-o');

# %% [markdown]
# Modificamos ligeramente la funcion
#
# $x_{n+1}=x_n^2+0.2$

# %%
# puntos fijos
def f2(x):
  return x*x+0.2

# %%
# multiples condiciones iniciales
T = 15
xini = [0, 0.1, 0.2, 0.3, 0.5, 0.6,0.7,0.723,0.724]
for x in xini:
  xn = [x]
  for t in range(T):
    x = f2(x)
    xn.append(x)
  plt.plot(xn,'-o');
  plt.grid()

# %%
(1-np.sqrt(0.2))/2
# Out:
# 0.27639320225002106

# %%
# Graficamos trayectorias
T = 15
xini = [0, 0.1, 0.2, 0.3, 0.5, 0.6,0.7,0.723,0.724]
for x in xini:
  xn = [x]
  for t in range(T):
    x = f2(x)
    xn.append(x)
  plt.plot([1]*(T+1),xn,'.',alpha=0.1);
