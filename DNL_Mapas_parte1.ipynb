# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/meguia/DNL_unq/blob/main/DNL_mapas.ipynb)

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# # Funciones Iteradas

# %% [markdown]
# ## Funciones Lineales

# %% [markdown]
# Una Funcion me devuelve a la salida un **UNICO** valor que depende **SOLO** de la entrada (es **DETERMINISTA**).

# %%
def f(x):
  return np.sqrt(x)

# %%
f(150)
# Out:
# 12.24744871391589

# %% [markdown]
# **ITERAR** una funcion es volver a meter la salida de la funcion en la entrada (Feedback positivo), o bien volver a aplicar la funcion de forma **recursiva **

# %%
f(f(f(f(0.1))))
# Out:
# 0.8659643233600653

# %% [markdown]
# Mas claro es hacer una TABLA de valores sucesivos de la iteracion llamando $x_n$ a la n-esima iteracion de la funcion

# %%
x0 = 0.1
x1 = f(x0)
x2 = f(x1)
x3 = f(x2)
x4 = f(x3)
[x0,x1,x2,x3,x4]
# Out:
# [0.1,
#  0.31622776601683794,
#  0.5623413251903491,
#  0.7498942093324559,
#  0.8659643233600653]

# %% [markdown]
# Esto se puede hacer de forma recursiva usando un bucle *for* una cantidad fija de veces y guardando los valores $x_n$ en un array.
#
# **T** es la cantidad de veces que vamos a iterar, para aludir al **TIEMPO**. el array $x_n$ se llama **TRAYECTORIA** u **ORBITA**

# %%
T = 100
x = 0.1
xn = [x]
for t in range(T):
  x = f(x)
  xn.append(x)  
print(xn)
# Out:
# [0.1, 0.31622776601683794, 0.5623413251903491, 0.7498942093324559, 0.8659643233600653, 0.930572040929699, 0.9646616199111993, 0.9821718891880378, 0.9910458562488609, 0.9955128609158502, 0.9977539079932738, 0.9988763226712674, 0.9994380034155532, 0.9997189622166588, 0.9998594712341624, 0.999929733148366, 0.9999648659569825, 0.9999824328241884, 0.9999912163735182, 0.9999956081771151, 0.9999978040861465, 0.9999989020424704, 0.9999994510210846, 0.9999997255105046, 0.9999998627552429, 0.9999999313776191, 0.999999965688809, 0.9999999828444044, 0.9999999914222022, 0.9999999957111011, 0.9999999978555505, 0.9999999989277752, 0.9999999994638876, 0.9999999997319438, 0.9999999998659719, 0.9999999999329859, 0.9999999999664929, 0.9999999999832464, 0.9999999999916231, 0.9999999999958116, 0.9999999999979058, 0.9999999999989528, 0.9999999999994764, 0.9999999999997382, 0.9999999999998691, 0.9999999999999345, 0.9999999999999672, 0.9999999999999836, 0.9999999999999918, 0.9999999999999959, 0.9999999999999979, 0.9999999999999989, 0.9999999999999994, 0.9999999999999997, 0.9999999999999998, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.9999999999999999]

# %% [markdown]
# Y podemos graficar el resultado usando la funcion plot de matplotlib

# %%
T = 100
x = 0.1
xn = [x]
for t in range(T):
  x = f(x)
  xn.append(x)

# %%
rcParams['figure.figsize'] = (20, 5)
plt.plot(xn,'o-');

# %%
plt.semilogy(xn,'o-');

# %% [markdown]
# ## Funciones No Lineales

# %%
def f(x):
  return x*x

# %%
T = 10
x = 1.5
xn = [x]
for t in range(T):
  x = f(x)
  xn.append(x)
print(xn)
plt.semilogy(xn,'-o')
# Out:
# [1.5, 2.25, 5.0625, 25.62890625, 656.8408355712891, 431439.8832739892, 186140372879.47342, 3.4648238415709404e+22, 1.2005004253118409e+45, 1.441201271173911e+90, 2.0770611040332967e+180]

# %% [markdown]
# # Sistema Dinamico
#
# **Un sistema dinamico es un sistema que evoluciona en el tiempo siguiendo una regla determinista fija.**
#
# El sistema dinamico puede tener varias variables, en este caso estamos viendo la evolucion de una **unica** variable (x) por eso el sistema es **1D** (evoluciona en la recta)
#
# La Regla determinista es fija durante la evolucion pero puede depender de uno o mas **parametros**.
#
# Gran parte del estudio de los Sistemas Dinamicos se dedica a estudiar como cambian cualitativamente la evolucion temporal del sistema cuando cambian los parametros (Teoria de Bifurcaciones)

# %% [markdown]
# ## Mapa (sistema dinamico discreto en el tiempo)
# iteracion de una funcion en el tiempo
#
# $x_{n+1}=f(x_n)$
#
# Ejemplo funcion no lineal cuadratica
#
# $x_{n+1}=x_n^2$

# %%
# multiples condiciones iniciales
T = 12
xini = [0.01, 0.2, 0.5, 0.9, 0.999, 1]
for x in xini:
  xn = [x]
  for t in range(T):
    x = f(x)
    xn.append(x)
  plt.plot(xn,'-o');

# %% [markdown]
# Modificamos ligeramente la funcion
#
# $x_{n+1}=x_n^2+0.1$

# %%
# puntos fijos
def f2(x):
  return x*x+0.1

# %%
# multiples condiciones iniciales
T = 15
xini = [0, 0.1, 0.2, 0.3, 0.5, 0.6,0.7,0.8,0.85,0.885]
for x in xini:
  xn = [x]
  for t in range(T):
    x = f2(x)
    xn.append(x)
  plt.plot(xn,'-o');
  plt.grid()
